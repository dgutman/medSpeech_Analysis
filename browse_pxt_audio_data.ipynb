# %%
import os
from dotenv import load_dotenv

## I set the PIXELTABLE_PGDATA environment variable in the .env file so that pixeltable stores the data on my NVME Drive
## You need to import this before starting pixeltable.
load_dotenv()
import pixeltable as pxt

# %%
t =  pxt.get_table('hani89_asr_data.transcribe_compare')
t.head()
# Out:
# Connected to Pixeltable database at: postgresql+psycopg://postgres:@/pixeltable?host=/scr/dagutman/devel/medSpeech_Analysis/.pxtDataV2
#                    id                                              audio  \
# 0  train_sample_0.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
# 1  train_sample_1.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
# 2  train_sample_2.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
# 3  train_sample_3.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
# 4  train_sample_4.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
# 5  train_sample_5.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
# 6  train_sample_6.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
# 7  train_sample_7.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
# 8  train_sample_8.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
# 9  train_sample_9.wav  /scr/dagutman/devel/medSpeech_Analysis/train_d...
#
#              filename                                      transcription  \
# 0  train_sample_0.wav        I feel dizzy after doing a muscular effort.
# 1  train_sample_1.wav             I break out on my face very frequently
# 2  train_sample_2.wav        Sometimes my body feels week without reason
# 3  train_sample_3.wav  There feels like a swollen knot at my shoulder...
# 4  train_sample_4.wav  When I get out of bed in the morning my body f...
# 5  train_sample_5.wav  My knee feels weak and it gave way the other d...
# 6  train_sample_6.wav                  The pain in my ear is unbearable.
# 7  train_sample_7.wav  When I wake up in the morning I feel a sorenes...
# 8  train_sample_8.wav         My stomach aches when I eat hot food, why?
# 9  train_sample_9.wav                            My throught is so sore.
#
#    split                       filePath  \
# 0  train  train_data/train_sample_0.wav
# 1  train  train_data/train_sample_1.wav
# 2  train  train_data/train_sample_2.wav
# 3  train  train_data/train_sample_3.wav
# 4  train  train_data/train_sample_4.wav
# 5  train  train_data/train_sample_5.wav
# 6  train  train_data/train_sample_6.wav
# 7  train  train_data/train_sample_7.wav
# 8  train  train_data/train_sample_8.wav
# 9  train  train_data/train_sample_9.wav
#
#                         whisper_tinyEn_transcription  \
# 0  {'text': ' I feel dizzy after doing a muscular...
# 1  {'text': ' I break out on my face very frequen...
# 2  {'text': ' Sometimes my body feels weak withou...
# 3  {'text': ' They feel like a swollen knot at my...
# 4  {'text': ' When I get out of bed in the mornin...
# 5  {'text': ' My knee feels weak and it gave away...
# 6  {'text': ' The pain in my ear is unbearable.',...
# 7  {'text': ' When I wake up in the morning, I fe...
# 8  {'text': ' My stomach eggs when I eat hot food...
# 9  {'text': ' My throat is so solid.', 'language'...
#
#                        whisper_smallEn_transcription  \
# 0  {'text': ' I feel dizzy after doing a muscular...
# 1  {'text': ' I break out on my face very frequen...
# 2  {'text': ' Sometimes my body feels weak withou...
# 3  {'text': ' There feels like a swollen knot at ...
# 4  {'text': ' When I get out of bed in the mornin...
# 5  {'text': ' My knee feels weak and it gave way ...
# 6  {'text': ' The pain in my ear is unbearable.',...
# 7  {'text': ' When I wake up in the morning, I fe...
# 8  {'text': ' My stomach aches when I eat hot foo...
# 9  {'text': ' My throat is so sore.', 'language':...
#
#                       whisper_mediumEn_transcription  \
# 0  {'text': ' I feel dizzy after doing a muscular...
# 1  {'text': ' I break out on my face very frequen...
# 2  {'text': ' Sometimes my body feels weak withou...
# 3  {'text': ' There feels like a swollen knot at ...
# 4  {'text': ' When I get out of bed in the mornin...
# 5  {'text': ' My knee feels weak and it gave away...
# 6  {'text': ' The pain in my ear is unbearable.',...
# 7  {'text': ' When I wake up in the morning, I fe...
# 8  {'text': ' My stomach aches when I eat hot foo...
# 9  {'text': ' My throat is so sore.', 'language':...
#
#                          whisper_large_transcription  \
# 0  {'text': ' I feel dizzy after doing a muscular...
# 1  {'text': ' I break out on my face very frequen...
# 2  {'text': ' Sometimes my body feels weak withou...
# 3  {'text': ' There feels like a swollen knot at ...
# 4  {'text': ' When I get out of bed in the mornin...
# 5  {'text': ' My knee feels weak and it gave away...
# 6  {'text': ' The pain in my ear is unbearable.',...
# 7  {'text': ' কন সব্দে আমানে সুত্ত্রাকা সে সুত্রা...
# 8  {'text': ' My stomach aches when I eat hot foo...
# 9  {'text': ' My throat is so sore.', 'language':...
#
#                         whisper_baseEn_transcription  \
# 0  {'text': ' I feel dizzy after doing a muscular...
# 1  {'text': ' I break out on my face very frequen...
# 2  {'text': ' Sometimes my body will speak withou...
# 3  {'text': ' There feels like a swollen knot at ...
# 4  {'text': ' When I get out of bed in the mornin...
# 5  {'text': ' My knee feels weak and it gave away...
# 6  {'text': ' The pain in my ear is unbearable.',...
# 7  {'text': ' When I wake up in the morning, I fe...
# 8  {'text': ' My stomach aches when I eat hot foo...
# 9  {'text': ' My throat is so sore.', 'language':...
#
#                          whisper_turbo_transcription
# 0  {'text': ' I feel dizzy after doing a muscular...
# 1  {'text': ' I break out on my face very frequen...
# 2  {'text': ' Sometimes my body feels weak withou...
# 3  {'text': ' There feels like a swollen knot at ...
# 4  {'text': ' When I get out of bed in the mornin...
# 5  {'text': ' My knee feels weak and it gave way ...
# 6  {'text': ' The pain in my ear is unbearable.',...
# 7  {'text': ' When I wake up in the morning, I fe...
# 8  {'text': ' My stomach aches when I eat hot foo...
# 9  {'text': ' My throat is so sore', 'language': ...

# %%
alreadyLoadedFiles = t.select(t.filePath).collect()['filePath']
