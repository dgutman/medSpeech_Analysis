# %%
import pixeltable as pxt
import datasets
from datasets import load_dataset


# @dataset{united_medsyn,
#   title={United-MedSyn: Medical Speech Dataset for ASR},
#   author={United We Care},
#   year={2024},
#   license={CC BY-SA 4.0}
# }

# %%
import kagglehub



# Download latest version
path = kagglehub.dataset_download("ammarshafiq/healthcare-appointment-booking-calls-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 8.49M/8.49M [00:00<00:00, 96.9MB/s]
# Extracting files...
# Path to dataset files: /home/dagutman/.cache/kagglehub/datasets/ammarshafiq/healthcare-appointment-booking-calls-dataset/versions/1

# %%
# !pip install kagglehub
# Out:
# ...
#   Using cached kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# ...
# Using cached kagglehub-0.3.13-py3-none-any.whl (68 kB)
# ...

# %%
pxt.create_dir('test_loader', if_exists='ignore')

# %%
### Medical data sets..

# %%
ds_medDialog_AudioV2 = load_dataset('aline-gassenn/MedDialog-Audio_v2')
# Out:
# ...
# Loading dataset shards:   0%|          | 0/43 [00:00<?, ?it/s]

# %%
ds_medDialog_AudioV2
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio'],
#         num_rows: 21068
#     })
# })
